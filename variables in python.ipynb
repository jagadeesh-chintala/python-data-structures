# %%
a=70.8
print(type(a))
# Out:
# <class 'float'>

# %%
round(90.5,0)
# Out:
# 90.0

# %%
a="sohi"
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 a="sohi"
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'sohi'

# %%
a=65
b=str(a)
print(b)
type(a)
# Out:
# 65
# int

# %%
type(b)
# Out:
# str

# %%
s=int(a)

# %%
type(s)
# Out:
# int

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=10.5
print(b)
print(type(b))
# Out:
# 10.5
# <class 'float'>

# %%
c="jaggu"
print(c)
print(type(c))
# Out:
# jaggu
# <class 'str'>

# %%
d=float(a)
print(d)
print(type(d))
# Out:
# 10.0
# <class 'float'>

# %%
e=int(d)
print(e)
print(type(e))
# Out:
# 10
# <class 'int'>

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=10
b=20
c=a-b
print(c)
# Out:
# -10

# %%
a=10
b=20
c=a*b
print(c)
# Out:
# 200

# %%
a=10
b=20
c=a/b
print(c)
# Out:
# 0.5

# %%
a=10
b=20
c=a//b
print(c)
# Out:
# 0

# %%
a=10
b=20
c=a**b
print(c)
# Out:
# 100000000000000000000

# %%
def sum(a,b):
    return a+b
sum(10,20)
# Out:
# 30

# %%
def sub(a,b):
    return a-b
sub(10,20)
# Out:
# -10

# %%
def mul(a,b):
    return a*b
mul(10,20)
# Out:
# 200

# %%
def div(a,b):
    return a/b
div(10,20)
# Out:
# 0.5

# %%
import math
a=10.5
print(math.floor(a))
# Out:
# 10

# %%
import math
a=10.5
print(math.ceil(a))
# Out:
# 11
