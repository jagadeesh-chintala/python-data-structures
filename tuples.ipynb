# %%
list=[1,2,3,4]
len(list)
# Out:
# 4

# %%
list[0]
# Out:
# 1

# %%
list[4:5]
# Out:
# []

# %%
list[0:1]
# Out:
# [1]

# %%
t=(1,2,3,4)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
new_t=(5,)
print(new_t)
# Out:
# (5,)

# %%
tu=("hello",7,"world")
print(tu)
# Out:
# ('hello', 7, 'world')

# %%
tu[0][2:4]
# Out:
# 'll'

# %%
tu[-3][2:4]
# Out:
# 'll'

# %%
tu[-3][-3:-1]
# Out:
# 'll'

# %%
nest=(1,2,3,(4,5))
nest
# Out:
# (1, 2, 3, (4, 5))

# %%
len(nest)
# Out:
# 4

# %%
nest[3][0]
# Out:
# 4

# %%
nest[-1][-2]
# Out:
# 4

# %%
nest[3][-2]
# Out:
# 4

# %%
nest[-2]
# Out:
# 3

# %%
nest[-2:]
# Out:
# (3, (4, 5))

# %%
t1=("jaggu",7,"anu",52)
t1
# Out:
# ('jaggu', 7, 'anu', 52)

# %%
t1[0][0:4]
# Out:
# 'jagg'

# %%
#indexing

fruits = ("Apple", "Banana", "Mango", "Orange")

print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
# Out:
# Apple
# Banana
# Mango
# Orange

# %%
fruits = ("Apple", "Banana", "Mango", "Orange")

print(fruits[-4])
print(fruits[-2])
print(fruits[-3])
print(fruits[-1])
# Out:
# Apple
# Mango
# Banana
# Orange

# %%
fruits[0:]
# Out:
# ('Apple', 'Banana', 'Mango', 'Orange')

# %%
fruits[2][0:3]
# Out:
# 'Man'

# %%
#slicing

numbers = (10, 20, 30, 40, 50, 60, 70)
numbers
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
numbers[0:4]
# Out:
# (10, 20, 30, 40)

# %%
numbers[0:]
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
numbers[::6]
# Out:
# (10, 70)

# %%
numbers[:4]
# Out:
# (10, 20, 30, 40)

# %%
sum(numbers)
# Out:
# 280

# %%
min(numbers)
# Out:
# 10

# %%
max(numbers)
# Out:
# 70

# %%
num=(10,20,30,"jaggu")
sum(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 num=(10,20,30,"jaggu")
# ----> 2 sum(num)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t0=("hello","world",5,10,"welcome","to","python")
t0

li=list(t0)
li
# Out:
# ['hello', 'world', 5, 10, 'welcome', 'to', 'python']

# %%
del list

# %%
li[0]="hii"

# %%
li
# Out:
# ['hii', 'world', 5, 10, 'welcome', 'to', 'python']

# %%
li.append('data analytics')
li
# Out:
# ['hii', 'world', 5, 10, 'welcome', 'to', 'python', 'data analytics']

# %%
numbers[::-1]
# Out:
# (70, 60, 50, 40, 30, 20, 10)

# %%
li[2]="to"
li[3]="the"
li
# Out:
# ['hii', 'world', 'to', 'the', 'welcome', 'to', 'python', 'data analytics']
