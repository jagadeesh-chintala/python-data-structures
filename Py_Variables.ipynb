# %% [markdown]
# Variables

# %%
a=89.9

# %%
a=int(a)

# %%
a
# Out:
# 89

# %%
type(a)
# Out:
# int

# %%
a=float(a)

# %%
a
# Out:
# 89.0

# %%
type(a)
# Out:
# float

# %%
round(99.5,0)
# Out:
# 100.0

# %%
a="5.5"
a=float(a)

# %%
a
# Out:
# 5.5

# %%
mystr="Pulla"
mystr=int(mystr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7978/682053365.py in <cell line: 0>()
#       1 mystr="Pulla"
# ----> 2 mystr=int(mystr)
#
# ValueError: invalid literal for int() with base 10: 'Pulla'

# %%
mystr="Pulla"
mystr=float(mystr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7978/2417555312.py in <cell line: 0>()
#       1 mystr="Pulla"
# ----> 2 mystr=float(mystr)
#
# ValueError: could not convert string to float: 'Pulla'

# %%
a="Pulla"

# %%
a
# Out:
# 'Pulla'

# %%
type(a)
# Out:
# str
