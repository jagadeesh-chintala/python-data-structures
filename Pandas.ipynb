# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# sort your df based on age

# %%
df.sort_values("SeniorCitizen")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 28    5248-YGIJN    Male              0     Yes         No      72
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 7024  7398-LXGYX    Male              0     Yes         No      44
# ...          ...     ...            ...     ...        ...     ...
# 31    4929-XIHVW    Male              1     Yes         No       2
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 34    3413-BMNZE    Male              1      No         No       1
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 28            Yes           Yes             DSL            Yes  ...
# ...

# %%
new_df=df.sort_values("SeniorCitizen")

# %%
new_df=df.head(5)

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
# add a column

# %%
df['MonthlyCharges']+1000
# Out:
# 0       1029.85
# 1       1056.95
# 2       1053.85
# 3       1042.30
# 4       1070.70
#          ...
# 7038    1084.80
# 7039    1103.20
# 7040    1029.60
# 7041    1074.40
# 7042    1105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
# How to create column

# %%
df['Random column']=

# %%
# how to access rows

# %%
# where monthly charges greater than 1000

# %%
df[df.MonthlyCharges>20]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
charges=df[df.MonthlyCharges>20]

# %%
len(charges)
# Out:
# 6387

# %%
len(df)
# Out:
# 7043

# %%
# How to fill the null values

# %%
df['MonthlyCharges'].fillna(10)
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
# Remove or delete one of the column

# %%
df.pop('MultipleLines')
# Out:
# 0       No phone service
# 1                     No
# 2                     No
# 3       No phone service
# 4                     No
#               ...
# 7038                 Yes
# 7039                 Yes
# 7040    No phone service
# 7041                 Yes
# 7042                  No
# Name: MultipleLines, Length: 7043, dtype: object

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
df['MultipleLines']=20

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   InternetService OnlineSecurity OnlineBackup  ... TechSupport StreamingTV  \
# 0             DSL             No          Yes  ...          No          No
# 1             DSL            Yes           No  ...          No          No
# 2             DSL            Yes          Yes  ...          No          No
# 3             DSL            Yes           No  ...         Yes          No
# 4     Fiber optic             No           No  ...          No          No
#
# ...

# %%
df['MultipleLines'].fillna(10)
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 7038    20
# 7039    20
# 7040    20
# 7041    20
# 7042    20
# Name: MultipleLines, Length: 7043, dtype: int64

# %%
import numpy as np
df['MonthlyCharges'].apply(np.sqrt)
# Out:
# 0        5.463515
# 1        7.546522
# 2        7.338256
# 3        6.503845
# 4        8.408329
#           ...
# 7038     9.208692
# 7039    10.158740
# 7040     5.440588
# 7041     8.625543
# 7042    10.278619
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
# Concat & Merging
# joins=Inner,Left,Right,Full

# %%
import pandas as pd
df1=pd.DataFrame({'A':['AB','AC','AD'],
                  'B':['BA','BB','BC']})

# %%
df1
# Out:
#     A   B
# 0  AB  BA
# 1  AC  BB
# 2  AD  BC

# %%
df2=pd.DataFrame({'A':['AB','AC','AD'],
                  'C':['BA','BB','BC']})

# %%
df2
# Out:
#     A   C
# 0  AB  BA
# 1  AC  BB
# 2  AD  BC

# %%
merge_df=pd.merge(df1,df2,how='inner')

# %%
merge_df
# Out:
#     A   B   C
# 0  AB  BA  BA
# 1  AC  BB  BB
# 2  AD  BC  BC

# %%
# loc & iloc
# loc get a rows (and /or column) with particular lables
# iloc get rows(and/or column) with location

# %%
import pandas as pd
s=pd.Series(list("abcdef"),index=[49,48,47,0,1,2])

# %%
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s.loc[0]
# value at the index lable1
# Out:
# 'd'

# %%
s.loc[1]
# Out:
# 'e'

# %%
s.iloc[0]
# value at index location
# Out:
# 'a'

# %%
s.iloc[1]
# Out:
# 'b'

# %%
s.loc[0:1]
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1]
# Out:
# 49    a
# dtype: object

# %%
# what if we sort the series

# %%
s1=s.sort_index()

# %%
s1
# Out:
# 0     d
# 1     e
# 2     f
# 47    c
# 48    b
# 49    a
# dtype: object

# %%
s1.iloc[0]
# Out:
# 'd'

# %%
s1.loc[0]
# Out:
# 'd'

# %% [markdown]
# ## **Matplotlib**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data = {"year":[1920,1930,1940,1950,1960,1970,1980,1990,2020],"exchange_rate": [65,66,67,68,69,70,71,72,73]}

type(Data)
# Out:
# dict

# %%
df = pd.DataFrame(Data)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.plot(x="year",y="exchange_rate",kind="line")
# Out:
# <Axes: xlabel='year'>

# %%
df.plot(x="year",y="exchange_rate",kind="scatter")
# Out:
# <Axes: xlabel='year', ylabel='exchange_rate'>

# %%
df.plot(x="year",y="exchange_rate",kind="barh")
# Out:
# <Axes: ylabel='year'>

# %%
Data = {'Tasks':[100,500,800]}
df = pd.DataFrame(Data,columns=['Tasks'],index=['pnding','completed','ongoing'])

# %%
df.plot.pie(y='Tasks',figsize=(5,5))
# Out:
# <Axes: ylabel='Tasks'>

# %%
Data = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn (1).csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df = pd.DataFrame(Data)
df.plot(x="MonthlyCharges",y="tenure",kind="bar")
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
plt.figure(figsize=(8, 8))
plt.pie(Data['MonthlyCharges'], labels=Data['PaymentMe'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Scores')
plt.axis('equal')
plt.show()

# %%
plt.scatter(Data['MonthlyCharges'],Data['TotalCharges'])
plt.title("Scatter plot")
plt.xlabel("This is x-axis")
plt.ylabel("This is y-axis")
plt.show()
