# %%
#over a numbers
l=[10,20,30,40,50]
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#over a string
str="jaggu"
for i in str:
    print(i)
# Out:
# j
# a
# g
# g
# u

# %%
#over dictionary

stu={
    1:["jaggu",21],
    2:["anu",20],
    3:["rohith,23"]
}
for i in stu.items():
    print(i)
# Out:
# (1, ['jaggu', 21])
# (2, ['anu', 20])
# (3, ['rohith,23'])

# %%
stu={
    1:["jaggu",21],
    2:["anu",20],
    3:["rohith,23"]
}
for i,j in stu.items():
    print(j[0])
# Out:
# jaggu
# anu
# rohith,23

# %%
#ovr range values

stu.get(2)[0]
# Out:
# 'anu'
