# %%
with open("sample.txt","w") as file:
   file.write("Hello students\n")
   file.write("welcome to DA course\n")
   file.write("Partik sir is trainer")
file=open("sample.txt","r")
for line in file:
  print(line)
# Out:
# Hello students
#
# welcome to DA course
#
# Partik sir is trainer

# %%
file=open("sample.txt","r")
print(file.read(11))
# Out:
# Hello stude

# %%
file=open("sample.txt","r")
print(file.readline())
# Out:
# Hello students
