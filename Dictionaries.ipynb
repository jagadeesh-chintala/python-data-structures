# %%
dic={
    "python":1,
    "java":2,
    "sql":3,
    "data analysis":4
}
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 3, 'data analysis': 4}

# %%
#accessing

dic["python"]
#print(dic)
dic["java"]
#print(dic)
# Out:
# 2

# %%
#replacing value

dic["sql"]=4
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 4, 'data analysis': 4}

# %%
#inserting

dic["full stack"]=5
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 4, 'data analysis': 4, 'full stack': 5}

# %%
#deleting
del dic["sql"]
dic
# Out:
# {'python': 1, 'java': 2, 'data analysis': 4, 'full stack': 5}

# %%
#sorting
s=sorted(dic)
print(s)
# Out:
# ['data analysis', 'full stack', 'java', 'python']

# %%
#value() method
dic.values()
# Out:
# dict_values([1, 2, 3, 5])

# %%
#key() method
dic.keys()
# Out:
# dict_keys(['python', 'java', 'data analysis', 'full stack'])

# %%
#get() method
dic.get("java")
# Out:
# 2

# %%
#update() method
dic.update({"data analysis":3})
dic
# Out:
# {'python': 1, 'java': 2, 'data analysis': 3, 'full stack': 5}

# %%
emp={
    101:["jaggu",20,"data analyst"],
    102:["pratik",27,"manager"],
    103:["anu",25,"developer"],
    104:["prasad",18,"accountant"],
    105:["rohith",20,"snr.scientist"]
}
emp
# Out:
# {101: ['jaggu', 20, 'data analyst'],
#  102: ['pratik', 27, 'manager'],
#  103: ['anu', 25, 'developer'],
#  104: ['prasad', 18, 'accountant'],
#  105: ['rohith', 20, 'snr.scientist']}

# %%
emp[101][2]
# Out:
# 'data analyst'

# %%
input_dict={
    "name":"jaggu",
    "profession":"data analyst"
}
key=input("enter the key:")
if key in input_dict:
    print(input_dict[key])
else:
    print("NA")
# Out:
# enter the key:age
# NA
