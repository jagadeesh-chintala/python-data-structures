# %%
dic={
    "python":1,
    "java":2,
    "sql":3,
    "data analysis":4
}
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 3, 'data analysis': 4}

# %%
#accessing

dic["python"]
#print(dic)
dic["java"]
#print(dic)
# Out:
# 2

# %%
#replacing value

dic["sql"]=4
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 4, 'data analysis': 4}

# %%
#inserting

dic["full stack"]=5
dic
# Out:
# {'python': 1, 'java': 2, 'sql': 4, 'data analysis': 4, 'full stack': 5}

# %%
#deleting
del dic["sql"]

# %%
#sorting

# %%
#value() method

# %%
#key() method

# %%
#get() method

# %%
#update() method
