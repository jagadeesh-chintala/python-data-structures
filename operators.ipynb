# %%
a=10
print(a)
b=2
c=a+b
print(c)
print(a+b)
# Out:
# 10
# 12
# 12

# %%
a=5.5
b='5'
print(a+int(b))
# Out:
# 10.5

# %%
a=10
b=2.5
a-b
# Out:
# 7.5

# %%
a=15.5
b="5"
print(a-int(b))
# Out:
# 10.5

# %%
a=5
b=10
c=a*b
print(c)
# Out:
# 50

# %%
a=5
b="10"
print(a*int(b))
# Out:
# 50

# %%
a=25
b=5
c=a/b
d=a//b
e=a%b
print(c)
print(d)
print(e)
# Out:
# 5.0
# 5
# 0

# %%
a=20
b=7
c=a%b
print(c)
# Out:
# 6

# %%
a=4
b=3
c=a**b
print(c)
# Out:
# 64

# %%
a=3
b=4
c=a%b
print(c)
# Out:
# 3

# %%
print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
print(4+(8**2)-3**2%1)
# Out:
# 68

# %%
print(4%(1+9)**2-60//(7+2))
# Out:
# -2

# %%
a=25
b=50
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
print(a//b)
print(a%b)
# Out:
# 75
# -25
# 1250
# 0.5
# 7888609052210118054117285652827862296732064351090230047702789306640625
# 0
# 25

# %%
print(25-(4//7)+5//2)
# Out:
# 27
