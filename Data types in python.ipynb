# %%
tuple=(1,2,3,4)
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
tu=1,2,3,4
print(type(tu))
# Out:
# <class 'tuple'>

# %%
t=(1,2,3,[4,5,6])
print(t)
print(type(t))
# Out:
# (1, 2, 3, [4, 5, 6])
# <class 'tuple'>

# %%
li=[1,2,3,(5,6,7)]
print(li)
print(type(li))
# Out:
# [1, 2, 3, (5, 6, 7)]
# <class 'list'>

# %%
#strings
string_var="hello"
res=list(string_var)

# %%
res[0]='y'
print(res)
# Out:
# ['y', 'e', 'l', 'l', 'o']

# %%
#numbers
x=10
print(id(x))

x=x+5
print(x)
print(id(x))
# Out:
# 140726816576584
# 15
# 140726816576744

# %%
#tuples
student = ("John", 25, "Python")

print(student)
print(student[0])
print(student[1])
# Out:
# ('John', 25, 'Python')
# John
# 25

# %%
number=10,20,30
number[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 number=10,20,30
# ----> 2 number[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#lists

fruits = ["Apple", "Banana", "Orange"]

print(fruits)
print(fruits[0])

fruits[1] = "Mango"

print(fruits)
# Out:
# ['Apple', 'Banana', 'Orange']
# Apple
# ['Apple', 'Mango', 'Orange']

# %%
#dictionaries
student = {
    "name": "John",
    "age": 25,
    "course": "Python"
}

print(student)

print(student["name"])

student["age"] = 26

print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'Python'}
# John
# {'name': 'John', 'age': 26, 'course': 'Python'}

# %%
#sets
numbers = {10, 20, 30, 40, 20}

print(numbers)

numbers.add(50)

print(numbers)
# Out:
# {40, 10, 20, 30}
# {40, 10, 50, 20, 30}
