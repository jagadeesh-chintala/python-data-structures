# %%
x=int(input("enter ur age:"))
if x%2==0:
    print(x,"is an even number")
else:
    print(x,"is a odd number")
# Out:
# enter ur age:14
# 14 is an even number

# %%
x=int(input("enter ur age:"))
if x< 18 or x>50:
    print("you are not allowed")
else:
    print("welcome to party in mits")
# Out:
# enter ur age:15
# you are not allowed

# %%
m=int(input("enter amount:"))
if m>5000:
    print("1000 discount")
elif m<2500 or m>5000:
    print("500 discount")
else:
    print("nothing")
# Out:
# enter amount:5000
# nothing
