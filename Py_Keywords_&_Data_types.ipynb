# %% [markdown]
# Keywords

# %%
if=3
# Out:
#   File "/tmp/ipykernel_1666/202199290.py", line 1
#     if=3
#       ^
# SyntaxError: invalid syntax

# %%
else="LK"

# %%
3k=5;

# %% [markdown]
# Datatypes

# %%
l=[1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
t=1,2,3,4,5
print(t)
# Out:
# (1, 2, 3, 4, 5)

# %%
t=(1,2,3,4,[5,6,7])

# %%
t
# Out:
# (1, 2, 3, 4, [5, 6, 7])

# %%
l=[1,2,3,4,(5,6,7)]

# %%
l
# Out:
# [1, 2, 3, 4, (5, 6, 7)]

# %%
s="Hello"
s.replace('H','Y')
# Out:
# 'Yello'

# %%
print(s[-1])
print(s[4])
# Out:
# o
# o
